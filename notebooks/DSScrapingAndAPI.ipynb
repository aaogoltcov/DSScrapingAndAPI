# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %%
import requests
from bs4 import BeautifulSoup as soup
import re
import time
import pandas as pd
import json

# %%
def get_posts(page_link, keyword, post_list):
    for post in soup(requests.get(page_link, params={'q': keyword,}).text, 'html.parser').find_all('a', class_='post__title_link'):
        post_link = post.get('href')
        post = soup(requests.get(post_link).text, 'html.parser')
        post_list.append({'keyword': keyword,
                          'date': post.find('span', class_='post__time').get('data-time_published'), 
                          'header': post.find('span', class_='post__title-text').text, 
                          'post_link': post_link, 
                          'post_text': post.find(id="post-content-body").text})
    return post_list

def get_search_result(keywords):
    post_list = []
    for keyword in keywords:
        last_page = (int(re.search(r'(page)(\d+)', 
                                   soup(requests.get('https://habr.com/ru/search/', params={'q': keyword,})
                                   .text, 'html.parser')
                                   .find('a', class_='toggle-menu__item-link_bordered')
                                   .get('href')).group(2)))
        for page in range(1, last_page + 1):
            get_posts(f'https://habr.com/ru/search/', keyword, post_list) if page == 1 else get_posts(f'https://habr.com/ru/search/page{page}/', keyword, post_list)
    return post_list

keywords = ['python', 'парсинг']
df = pd.DataFrame(get_search_result(keywords))
df
# Out:
#       keyword               date  \
# 0      python  2020-04-21T15:35Z
# 1      python  2020-03-03T10:22Z
# 2      python  2020-06-03T06:00Z
# 3      python  2019-10-31T07:02Z
# 4      python  2012-07-09T06:21Z
# ...       ...                ...
# 1994  парсинг  2014-08-21T15:41Z
# 1995  парсинг  2014-08-25T07:41Z
# 1996  парсинг  2014-09-02T09:26Z
# 1997  парсинг  2014-09-04T07:10Z
# 1998  парсинг  2014-09-19T11:48Z
#
#                                                  header  \
# 0     Вышел Python 2.7.18, последний релиз ветки Pyt...
# 1     В начале этого года Python сместил Java и стал...
# 2     Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 3     Создатель Python Гвидо ван Россум ушел из Drop...
# 4                                      Мысли о Python 3
# ...                                                 ...
# 1994              mysqlnd — проводник между PHP и MySQL
# 1995  Несколько интересностей и полезностей от веб-р...
# 1996            Приглашаем на Moscow Django MeetUp № 22
# 1997                Основные отличия Java IO и Java NIO
# 1998  О тонкостях «шифрованного трубопровода» в проц...
#
#                                               post_link  \
# 0                    https://habr.com/ru/news/t/498364/
# 1     https://habr.com/ru/company/itsumma/news/t/490...
# 2                    https://habr.com/ru/news/t/505096/
# 3                    https://habr.com/ru/news/t/473926/
# 4                      https://habr.com/ru/post/147281/
# ...                                                 ...
# 1994    https://habr.com/ru/company/mailru/blog/234125/
# 1995                   https://habr.com/ru/post/234279/
# 1996    https://habr.com/ru/company/mailru/blog/235227/
# 1997                   https://habr.com/ru/post/235585/
# 1998                   https://habr.com/ru/post/237427/
#
#                                               post_text
# 0     \r\n20 апреля 2020 года, спустя почти десять л...
# 1     Согласно отчету RedMonk за январь 2020 года, P...
# 2     \n\r\n31 мая 2020 года разработчик Джош Мур (J...
# 3     \n\r\nСоздатель языка программирования Python ...
# 4     Предлагаю вашему вниманю пересказ замечательно...
# ...                                                 ...
# 1994  \n\r\nРасширение mysqlnd появилось ещё в PHP 5...
# 1995  * Надеюсь,  ilusha_sergeevich не обвинит меня ...
# 1996  \n\r\nДамы и господа, в четверг в офисе Mail.R...
# 1997  Когда я начал изучать стандартный ввод/вывод в...
# 1998  Совсем недавно я перешел с горячо любимого мно...
#
# [1999 rows x 5 columns]

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
def get_email_leak_status(emails):
    list_of_leaks = []
    for email in emails:
        for leak in requests.post('https://digibody.avast.com/v1/web/leaks', data=json.dumps({'email': email})).json()['value']:
            list_of_leaks.append({
                'email': email,
                'date_leak': leak['leak_info']['date'],
                'leak_source': leak['domain'],
                'leak_description': leak['leak_info']['description'],
            })
    return pd.DataFrame(list_of_leaks)

emails = ['aaogoltcov@mail.ru', 'alexey.ogoltsov@outlook.com',]
get_email_leak_status(emails)
# Out:
#                          email      date_leak      leak_source  \
# 0           aaogoltcov@mail.ru  1558569600000  livejournal.com
# 1           aaogoltcov@mail.ru  1549411200000
# 2           aaogoltcov@mail.ru  1549411200000
# 3           aaogoltcov@mail.ru  1571270400000        zynga.com
# 4           aaogoltcov@mail.ru  1509753600000   myheritage.com
# 5           aaogoltcov@mail.ru  1548720000000
# 6           aaogoltcov@mail.ru  1576195200000
# 7           aaogoltcov@mail.ru  1477958400000           qip.ru
# 8           aaogoltcov@mail.ru  1575504000000
# 9  alexey.ogoltsov@outlook.com  1509753600000   myheritage.com
#
#                                     leak_description
# 0  In 2017, social network LiveJournal's database...
# 1  On January 7, 2019, an online user named Sanix...
# 2  On January 7, 2019, an online user named Sanix...
# 3  In September 2019, the game developer Zynga wa...
# 4  In October 2017, a customer database belonging...
# 5  On January 7, 2019, an online user named Sanix...
# 6  This source has been marked as sensitive due t...
# 7  In 2011, Russian instant messaging service pro...
# 8  This source has been marked as sensitive due t...
# 9  In October 2017, a customer database belonging...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.

# %%
response = requests.get('https://api.vk.com/method/wall.get?', params = {
        'access_token': 'FILL ACCESS TOKEN',
        'v': 5.122,
        'domain': 'netology',
        'count': 50,
}).json()['response']['items']
list_of_posts = []
for post in response:
    list_of_posts.append({
        'post_date': post['date'],
        'post_text': post['text'],
    })
pd.DataFrame(list_of_posts)
# Out:
#      post_date                                          post_text
# 0   1598022840  А ю рэди? 🕺 На следующей неделе учимся выступа...
# 1   1598455920  Хорошие новости: мы почти нашли ведущего для н...
# 2   1598428200  Ой, сделайте меня стройнее, поставьте рядом Дж...
# 3   1598370120  Казалось бы, общение — это просто. Кто-то гово...
# 4   1598345789  Любимая работа, амбициозные проекты, полное по...
# 5   1598282460  Буквы разные писать, тонким пёрышком в тетрадь...
# 6   1598254680  SMM — это не только про креатив. Здесь важен р...
# 7   1598188440  Подкасты — отличный способ узнавать что-то нов...
# 8   1598170320  Вместе с командой приложения для проектировани...
# 9   1598102100  *партнерский пост* \n \n17-18 сентября пройдёт...
# 10  1598082600  Ладони потеют, колени подкашиваются, голос дро...
# 11  1598016602  Итоги карьерного квеста Нетологии🎉 \n \nМы хот...
# 12  1597995720  «Мужчина, вы что не видите, у меня обед»👀 \nВс...
# 13  1597934520  Бывало ли у вас чувство, что ваши успехи — лиш...
# 14  1597909080  Очень удобно, когда всё что нужно, находится р...
# 15  1597851720  Зарядка для мозга: сегодня решаем анаграммы 🧐\...
# 16  1597831206  Друзья, последнее пятое задание уже вышло, и с...
# 17  1597823400  Почувствовать себя дизайнером стало совсем про...
# 18  1597761720  Исследования показывают, что люди проводят поч...
# 19  1597741211  Осталась всего одна ступень до вершины!⚡\n \nВ...
# 20  1597736280  Последние дни лета всегда проходят под девизом...
# 21  1597678680  Зарядку сделали, перед зеркалом порепетировали...
# 22  1597654812  Как приятно видеть, что работа приносит резуль...
# 23  1597650120  Запустили бесплатный курс по основам контекстн...
# 24  1597580880  Подборка книг, которые помогут развить математ...
# 25  1597566624  Продвижение курса — дело непростое. Но у вас к...
# 26  1597491720  Личный бренд работает по принципу зачётки: сна...
# 27  1597480217  Как успехи у ваших студентов? Поздравляем, вы ...
# 28  1597477320  *партнерский пост*\n\nМеждународный конкурс по...
# 29  1597402812  А вот и первое задание карьерного квеста. Мене...
# 30  1597402808  Всем привет! Сегодня первый день карьерного кв...
# 31  1597390920  Больше, ещё больше знаний🤓 Разбираемся с дизай...
# 32  1597331640  «Нужно работать так, словно таланта у тебя воо...
# 33  1597304520  Составляем карту пути клиента, открываем калит...
# 34  1597246920  Вечер среды — самое время для поиска формулы б...
# 35  1597218120  Синдром самозванца — склонность преуменьшать с...
# 36  1597156920  Несколько советов, которые помогут держать зад...
# 37  1597130760  Закройте окошко — сквозит 🤧 Откройте отчёт — э...
# 38  1597069560  Фотку котика, загадочный пейзаж или всё-таки с...
# 39  1597044360  Запустили бесплатный курс «Старт в SMM»💛\n\nКа...
# 40  1596982440  Мир 🌏 меняется и нам приходится меняться вмест...
# 41  1596896040  Есть убеждение, что после сорока лет сложно ме...
# 42  1596885240  В этой подборке статей разгадываем загадки Exc...
# 43  1596809640  Остались силы для новый знаний? Свежее расписа...
# 44  1596801608  С места в карьеру: проходите карьерный квест Н...
# 45  1596788040  Могу ли я стать аналитиком без пятерки по школ...
# 46  1596726840  Прочитал страницу, очнулся, а о чем читал и не...
# 47  1596699720  Найти вдохновение не так просто: музу не дожде...
# 48  1596638520  Наш статус: в активном поиске 🔍\n\nДрузья, мы ...
# 49  1596613320  10 августа стартует бесплатный курс по основам...

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
